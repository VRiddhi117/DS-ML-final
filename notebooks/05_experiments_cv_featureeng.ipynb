# %%
# !pip install -q scikit-learn mlflow optuna matplotlib pandas numpy xgboost

# %%
# !pip install -q python-dotenv

# %%
from dotenv import load_dotenv
from pathlib import Path
import os

load_dotenv(Path("..") / ".env")   # loads your repo-root .env
print("Loaded env ✅")
# Out:
# Loaded env ✅

# %%
from dotenv import load_dotenv
from pathlib import Path
import os
import mlflow

load_dotenv(Path("..") / ".env")

mlflow.set_tracking_uri(os.getenv("MLFLOW_TRACKING_URI"))
mlflow.set_experiment("test_connection")

with mlflow.start_run():
    mlflow.log_metric("test_metric", 1.0)

print("✅ Logged test run to DagsHub")
# Out:
# 2025/12/17 23:59:35 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2025/12/17 23:59:35 INFO mlflow.store.db.utils: Updating database tables
# 2025/12/17 23:59:35 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2025/12/17 23:59:35 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# 2025/12/17 23:59:35 INFO alembic.runtime.migration: Running upgrade  -> 451aebb31d03, add metric step
# 2025/12/17 23:59:35 INFO alembic.runtime.migration: Running upgrade 451aebb31d03 -> 90e64c465722, migrate user column to tags
# 2025/12/17 23:59:35 INFO alembic.runtime.migration: Running upgrade 90e64c465722 -> 181f10493468, allow nulls for metric values
# 2025/12/17 23:59:35 INFO alembic.runtime.migration: Running upgrade 181f10493468 -> df50e92ffc5e, Add Experiment Tags Table
# 2025/12/17 23:59:35 INFO alembic.runtime.migration: Running upgrade df50e92ffc5e -> 7ac759974ad8, Update run tags with larger limit
# ...

# %%
from dotenv import load_dotenv
from pathlib import Path
import os

load_dotenv(Path(".") / ".env")   # notebooks/.env
print("Loaded .env from:", (Path(".") / ".env").resolve())
# Out:
# Loaded .env from: /Users/ar/Desktop/Riddhi/ESDS_Fall 2025/Pro Data science /Final Project/housing_app_fall25/notebooks/.env

# %%
import mlflow

mlflow.set_tracking_uri(os.getenv("MLFLOW_TRACKING_URI"))
mlflow.set_experiment("cosmetics_experiments_rubricB")

print("✅ MLflow connected:", mlflow.get_tracking_uri())
# Out:
# 2025/12/18 00:10:07 INFO mlflow.tracking.fluent: Experiment with name 'cosmetics_experiments_rubricB' does not exist. Creating a new experiment.
# ✅ MLflow connected: http://dagshub.com/rvaghani/my-first-repo.mlflow

# %%
with mlflow.start_run(run_name="sanity_check"):
    mlflow.log_metric("sanity_check", 1.0)
    mlflow.log_param("status", "ok")

print("✅ Test run logged")
# Out:
# 🏃 View run sanity_check at: http://dagshub.com/rvaghani/my-first-repo.mlflow/#/experiments/1/runs/c62d02c8e0e44a549ec55347a5a6cc7e
# 🧪 View experiment at: http://dagshub.com/rvaghani/my-first-repo.mlflow/#/experiments/1
# ✅ Test run logged
